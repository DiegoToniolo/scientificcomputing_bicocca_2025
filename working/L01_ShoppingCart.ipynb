# %% [markdown]
# # The Shopping Cart

# %% [markdown]
# ## The Item class

# %% [markdown]
# We begin from the definition of the Item class.

# %%
INVENTORY_TEXT = """
apple, 0.60
banana, 0.20
grapefruit, 0.75
grapes, 1.99
kiwi, 0.50
lemon, 0.20
lime, 0.25
mango, 1.50
papaya, 2.95
pineapple, 3.50
blueberries, 1.99
blackberries, 2.50
peach, 0.50
plum, 0.33
clementine, 0.25
cantaloupe, 3.25
pear, 1.25
quince, 0.45
orange, 0.60
"""

# this will be a global -- convention is all caps
INVENTORY = {}
for line in INVENTORY_TEXT.splitlines():
    if line.strip() == "":
        continue
    item, price = line.split(",")
    INVENTORY[item] = float(price)

# %%
class Item:
    """ an item to buy """
    
    def __init__(self, name, quantity=1):
        """keep track of an item that is in our inventory"""
        if name not in INVENTORY:
            raise ValueError("invalid item name")
        self.name = name
        if quantity < 0:
            raise ValueError("quantity must be non-negative")
        if not isinstance(quantity, int):
            raise ValueError("quantity must be an integer")
        self.quantity = quantity
        
    def __repr__(self):
        return "{}: {}".format(self.name, self.quantity)
        
    def __eq__(self, other):
        """check if the items have the same name"""
        return self.name == other.name
    
    def __add__(self, other):
        """add two items together if they are the same type"""
        if self.name == other.name:
            return Item(self.name, self.quantity + other.quantity)
        else:
            raise ValueError("names don't match")

# %% [markdown]
# Here some tests

# %%
#Define some items
a = Item("apple", 10)
b = Item("banana", 20)
c = Item("apple", 20)

# %%
#It does not work: different items
a+b
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 #It does not work: different items
# ----> 2 a+b
#
# Cell In[2], line 27, in Item.__add__(self, other)
#      25     return Item(self.name, self.quantity + other.quantity)
#      26 else:
# ---> 27     raise ValueError("names don't match")
#
# ValueError: names don't match

# %%
#It should work: same items
a+c
# Out:
# apple: 30

# %%
#Shoud give False
print(a == b)
#Shoud give True
print(a == c)
# Out:
# False
# True

# %%
#Should not work: negative quantity
Item("orange", -5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 #Should not work: negative quantity
# ----> 2 Item("orange", -5)
#
# Cell In[2], line 10, in Item.__init__(self, name, quantity)
#       8 self.name = name
#       9 if quantity < 0:
# ---> 10     raise ValueError("quantity must be non-negative")
#      11 if not isinstance(quantity, int):
#      12     raise ValueError("quantity must be an integer")
#
# ValueError: quantity must be non-negative

# %%
#Should not work: non-integer quantity
Item("orange", 2.5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 #Should not work: non-integer quantity
# ----> 2 Item("orange", 2.5)
#
# Cell In[2], line 12, in Item.__init__(self, name, quantity)
#      10     raise ValueError("quantity must be non-negative")
#      11 if not isinstance(quantity, int):
# ---> 12     raise ValueError("quantity must be an integer")
#      13 self.quantity = quantity
#
# ValueError: quantity must be an integer

# %%
items = []
items.append(a)
items.append(b)
items
# Out:
# [apple: 10, banana: 20]

# %%
c in items
# Out:
# True

# %% [markdown]
# ## The ShoppingCart class

# %%
class ShoppingCart:
    
    def __init__(self):
        # the list of items we control
        self.items = []
        
    def subtotal(self):
        """ return a subtotal of our items """
        sub = 0
        for i in self.items:
            sub += INVENTORY[i.name]*i.quantity
        return sub

    def add(self, name, quantity):
        """ add an item to our cart -- the an item of the same name already
        exists, then increment the quantity.  Otherwise, add a new item
        to the cart with the desired quantity."""
        try:
            item = Item(name, quantity)
        except ValueError:
            print(f"Error adding item: invalid name or quantity")
            return
        if item in self.items:
            i = self.items.index(item)
            self.items[i] = self.items[i] + item
        else:
            self.items.append(item)
        
    def remove(self, name):
        """ remove all of item name from the cart """
        try:
            item = Item(name)
        except ValueError:
            print(f"Error removing item: invalid name or quantity")
            return
        try:
            self.items.remove(Item(name))
        except ValueError:
            print(f"Error removing item: item not in the cart yet")
        
    def report(self):
        """ print a summary of the cart """
        print("Cart report:")
        for item in self.items:
            print(f"{item.name} : {item.quantity}")
        print(f"Subtotal: {self.subtotal()}")

# %%
sc = ShoppingCart()
sc.add("orange", 19)

# %%
sc.add("apple", 2)

# %%
sc.report()
# Out:
# Cart report:
# orange : 19
# apple : 2
# Subtotal: 12.6

# %%
sc.add("apple", 9)

# %%
# apple should only be listed once in the report, with a quantity of 11
sc.report()
# Out:
# Cart report:
# orange : 19
# apple : 11
# Subtotal: 18.0

# %%
sc.subtotal()
# Out:
# 18.0

# %%
sc.remove("apple")

# %%
# apple should no longer be listed
sc.report()
# Out:
# Cart report:
# orange : 19
# Subtotal: 11.4
